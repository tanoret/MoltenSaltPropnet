# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys

# Set correct path so "processing_mstdb" is importable
PROJECT_PATH = os.path.abspath(os.path.join(os.getcwd(), ".."))
print("Adding to sys.path:", PROJECT_PATH)
sys.path.insert(0, PROJECT_PATH)

# Now you can import your modules
from processing_mstdb.processor import MSTDBProcessor
from processing_mstdb.trainer import AIModelTrainer

# Load and preprocess the data
data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_processed.csv"))
# data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_janz_processed.csv"))
print("Loading data from:", data_path)

processor = MSTDBProcessor.from_csv(data_path)
processor.df.columns = processor.df.columns.str.strip()

# Specify composition type: 'elements', 'compounds', or 'both'
composition_type = 'both'  # Using 'elements' to match the prediction example below
# For 'compounds', use e.g., composition_type = 'compounds'
# For 'both', use composition_type = 'both'

processor.df['Composition'] = processor.df.apply(
    lambda row: processor.compute_composition(row, composition_type=composition_type), axis=1
)

# Step 2: Train models
trainer = AIModelTrainer(processor.df)
trainer.train_all()

# Step 3: Make prediction
# For composition_type='elements', provide elemental composition
example_composition = {'Na': 0.5, 'Cl': 0.5}
# For composition_type='compounds', provide compound composition, e.g., {'NaCl': 1.0}
# For composition_type='both', provide both, e.g., {'Na': 0.5, 'Cl': 0.5, 'NaCl': 1.0}
predicted_props = trainer.predict(example_composition)

# Step 4: Display results
print("\nPredicted Properties for example composition:")
for k, v in predicted_props.items():
    print(f"  {k}: {v:.4f}")

# Step 5: Show evaluation metrics
print("\nModel Performance Summary (R2 and MSE):")
metrics = trainer.get_metrics()
for target, scores in metrics.items():
    print(f"\nTarget: {target}")
    for model_name, result in scores.items():
        print(f"  {model_name}: R2 = {result['R2']:.4f}, MSE = {result['MSE']:.4f}")

# Step 6: Plot R2 scores
print("\nPlotting R2 scores")
plot_dir = "sklearn_prediction_plots"
os.makedirs(plot_dir, exist_ok=True)

for target, model_scores in metrics.items():
    model_names = list(model_scores.keys())
    r2_scores = [model_scores[m]['R2'] for m in model_names]
    plt.figure(figsize=(10, 5))
    plt.bar(model_names, r2_scores)
    plt.title(f"R² Scores for {target}")
    plt.ylabel("R²")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, f"r2_{target}.png"))
    plt.close()

# Step 7: Plot Actual vs Predicted for best models
print("\nPlot actual vs. predicted for best models coefficients")
from sklearn.metrics import r2_score

for target in trainer.present_target_columns:
    model_path = os.path.join("..", "data", "trained_models", f"{target}.joblib")
    scaler_path = os.path.join("..", "data", "trained_models", f"{target}_scaler.joblib")
    if not os.path.exists(model_path) or not os.path.exists(scaler_path):
        continue
    df_target = processor.df.dropna(subset=[target])
    X = pd.json_normalize(df_target['Composition']).fillna(0)
    X = X.reindex(sorted(X.columns), axis=1)
    X_poly = trainer.poly.transform(X)
    X_scaled = trainer.scalers[target].transform(X_poly)
    y_actual = pd.to_numeric(df_target[target], errors='coerce')
    model = trainer.best_models[target]
    y_pred = model.predict(X_scaled)
    plt.figure(figsize=(6, 6))
    plt.scatter(y_actual, y_pred, alpha=0.7)
    plt.plot([y_actual.min(), y_actual.max()], [y_actual.min(), y_actual.max()], 'r--')
    plt.title(f"Actual vs Predicted: {target}")
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, f"actual_vs_predicted_{target}.png"))
    plt.close()

# Step 8: Compute actual vs predicted thermophysical properties
print("\nPlot actual vs. predicted for best model physical properties")
temperature = 900  # Kelvin
os.makedirs(plot_dir, exist_ok=True)

# Clean up all coefficient columns to ensure they are numeric
coeff_cols = ['rho_a', 'rho_b', 'mu1_a', 'mu1_b',
              'mu2_a', 'mu2_b', 'mu2_c',
              'k_a', 'k_b', 'cp_a', 'cp_b', 'cp_c', 'cp_d']

for col in coeff_cols:
    if col in processor.df.columns:
        processor.df[col] = pd.to_numeric(processor.df[col], errors='coerce')

# Replace NaNs with 0.0
processor.df.fillna(0.0, inplace=True)

# Compute actual thermophysical properties
processor.df['Actual Properties'] = processor.df.apply(
    lambda row: processor.compute_actual_properties(row, temperature), axis=1
)

# Predict coefficients and compute predicted thermophysical properties
processor.df['Predicted Coeffs'] = processor.df['Composition'].apply(trainer.predict)
processor.df['Predicted Properties'] = processor.df['Predicted Coeffs'].apply(
    lambda pred: processor.compute_actual_properties_from_predictions(pred, temperature)
)

# Define which properties to compare
properties_to_compare = [
    "Density", "Viscosity A", "Thermal Conductivity", "Heat Capacity of Liquid"
]

# Plot comparisons
for prop in properties_to_compare:
    actual_vals = []
    predicted_vals = []
    skipped = 0
    for _, row in processor.df.iterrows():
        actual = row['Actual Properties'].get(prop)
        predicted = row['Predicted Properties'].get(prop)
        if actual is None or predicted is None or actual < 1e-6:
            skipped += 1
            continue
        actual_vals.append(actual)
        predicted_vals.append(predicted)
    if actual_vals and predicted_vals:
        plt.figure(figsize=(6, 6))
        plt.scatter(actual_vals, predicted_vals, alpha=0.7)
        plt.plot([min(actual_vals), max(actual_vals)], [min(actual_vals), max(actual_vals)], 'r--')
        plt.title(f"Actual vs Predicted {prop} at {temperature} K")
        plt.xlabel("Actual")
        plt.ylabel("Predicted")
        plt.grid(True)
        plt.tight_layout()
        fname = f"actual_vs_predicted_{prop.replace(' ', '_')}.png"
        plt.savefig(os.path.join(plot_dir, fname))
        plt.close()
        print(f"Saved: {fname} ({len(actual_vals)} points, {skipped} skipped)")
    else:
        print(f"Skipped {prop} — no valid data (all {skipped} rows filtered out).")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys

# Set correct path so "processing_mstdb" is importable
PROJECT_PATH = os.path.abspath(os.path.join(os.getcwd(), ".."))
print("Adding to sys.path:", PROJECT_PATH)
sys.path.insert(0, PROJECT_PATH)

# Now you can import your modules
from processing_mstdb.processor import MSTDBProcessor
from processing_mstdb.trainer import AIModelTrainer

# Load and preprocess the data
data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_processed.csv"))
# data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_janz_processed.csv"))
print("Loading data from:", data_path)

processor = MSTDBProcessor.from_csv(data_path)

# Specify composition type: 'elements', 'compounds', or 'both'
composition_type = 'both'  # Using 'elements' to match the prediction example below
# For 'compounds', use e.g., composition_type = 'compounds'
# For 'both', use composition_type = 'both'

processor.df['Composition'] = processor.df.apply(
    lambda row: processor.compute_composition(row, composition_type=composition_type), axis=1
)

# Define a filter
filter_dict = {
    "include": {
        "elements": ["Na", "Cl"],
        "compounds": ["NaCl"]
    }
}

# Apply the filter
processor = processor.filter_by_components(filter_dict)

# Reinitialize the trainer with the FILTERED data
trainer = AIModelTrainer(processor.df, embedding_method='pca', embedding_params={'n_components': 5})  # Use the filtered DataFrame
trainer.train_all()

# Predict with composition matching the filtered feature space
example_composition = {'Na': 0.5, 'Cl': 0.5, 'NaCl': 1.0}  # Include NaCl if needed
predicted_props = trainer.predict(example_composition)

# Step 4: Display results
print("\nPredicted Properties for example composition:")
for k, v in predicted_props.items():
    print(f"  {k}: {v:.4f}")

# Step 5: Show evaluation metrics
print("\nModel Performance Summary (R2 and MSE):")
metrics = trainer.get_metrics()
for target, scores in metrics.items():
    print(f"\nTarget: {target}")
    for model_name, result in scores.items():
        print(f"  {model_name}: R2 = {result['R2']:.4f}, MSE = {result['MSE']:.4f}")

# Step 6: Plot R2 scores
print("\nPlotting R2 scores")
plot_dir = "sklearn_prediction_plots"
os.makedirs(plot_dir, exist_ok=True)

for target, model_scores in metrics.items():
    model_names = list(model_scores.keys())
    r2_scores = [model_scores[m]['R2'] for m in model_names]
    plt.figure(figsize=(10, 5))
    plt.bar(model_names, r2_scores)
    plt.title(f"R² Scores for {target}")
    plt.ylabel("R²")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(plot_dir, f"r2_{target}.png"))
    plt.close()

# Step 7: Plot Actual vs Predicted for best models
print("\nPlot actual vs. predicted for best models coefficients")
from sklearn.metrics import r2_score

for target in trainer.present_target_columns:
    try:
        model_path = os.path.join("..", "data", "trained_models", f"{target}.joblib")
        scaler_path = os.path.join("..", "data", "trained_models", f"{target}_scaler.joblib")
        if not os.path.exists(model_path) or not os.path.exists(scaler_path):
            continue
        df_target = processor.df.dropna(subset=[target])
        X = pd.json_normalize(df_target['Composition']).fillna(0)
        X = X.reindex(sorted(X.columns), axis=1)
        X_poly = trainer.poly.transform(X)
        X_scaled = trainer.scalers[target].transform(X_poly)
        y_actual = pd.to_numeric(df_target[target], errors='coerce')
        model = trainer.best_models[target]
        y_pred = model.predict(X_scaled)
        plt.figure(figsize=(6, 6))
        plt.scatter(y_actual, y_pred, alpha=0.7)
        plt.plot([y_actual.min(), y_actual.max()], [y_actual.min(), y_actual.max()], 'r--')
        plt.title(f"Actual vs Predicted: {target}")
        plt.xlabel("Actual")
        plt.ylabel("Predicted")
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(os.path.join(plot_dir, f"actual_vs_predicted_{target}.png"))
        plt.close()
    except:
        pass

# Step 8: Compute actual vs predicted thermophysical properties
print("\nPlot actual vs. predicted for best model physical properties")
temperature = 900  # Kelvin
os.makedirs(plot_dir, exist_ok=True)

# Clean up all coefficient columns to ensure they are numeric
coeff_cols = ['rho_a', 'rho_b', 'mu1_a', 'mu1_b',
              'mu2_a', 'mu2_b', 'mu2_c',
              'k_a', 'k_b', 'cp_a', 'cp_b', 'cp_c', 'cp_d']

for col in coeff_cols:
    if col in processor.df.columns:
        processor.df[col] = pd.to_numeric(processor.df[col], errors='coerce')

# Replace NaNs with 0.0
processor.df.fillna(0.0, inplace=True)

# Compute actual thermophysical properties
processor.df['Actual Properties'] = processor.df.apply(
    lambda row: processor.compute_actual_properties(row, temperature), axis=1
)

# Predict coefficients and compute predicted thermophysical properties
processor.df['Predicted Coeffs'] = processor.df['Composition'].apply(trainer.predict)
processor.df['Predicted Properties'] = processor.df['Predicted Coeffs'].apply(
    lambda pred: processor.compute_actual_properties_from_predictions(pred, temperature)
)

# Define which properties to compare
properties_to_compare = [
    "Density", "Viscosity A", "Thermal Conductivity", "Heat Capacity of Liquid"
]

# Plot comparisons
for prop in properties_to_compare:
    actual_vals = []
    predicted_vals = []
    skipped = 0
    for _, row in processor.df.iterrows():
        actual = row['Actual Properties'].get(prop)
        predicted = row['Predicted Properties'].get(prop)
        if actual is None or predicted is None or actual < 1e-6:
            skipped += 1
            continue
        actual_vals.append(actual)
        predicted_vals.append(predicted)
    if actual_vals and predicted_vals:
        plt.figure(figsize=(6, 6))
        plt.scatter(actual_vals, predicted_vals, alpha=0.7)
        plt.plot([min(actual_vals), max(actual_vals)], [min(actual_vals), max(actual_vals)], 'r--')
        plt.title(f"Actual vs Predicted {prop} at {temperature} K")
        plt.xlabel("Actual")
        plt.ylabel("Predicted")
        plt.grid(True)
        plt.tight_layout()
        fname = f"actual_vs_predicted_{prop.replace(' ', '_')}.png"
        plt.savefig(os.path.join(plot_dir, fname))
        plt.close()
        print(f"Saved: {fname} ({len(actual_vals)} points, {skipped} skipped)")
    else:
        print(f"Skipped {prop} — no valid data (all {skipped} rows filtered out).")
# Out:
# Adding to sys.path: /Users/mauriciotano/projects/MoltenSaltPropnet
# Loading data from: /Users/mauriciotano/projects/MoltenSaltPropnet/data/mstdb_processed.csv
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.988e+03, tolerance: 3.367e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.551e+03, tolerance: 2.897e+02
#   model = cd_fast.enet_coordinate_descent(
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# ...
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1107: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1107: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# /Users/mauriciotano/miniforge/envs/scientific_env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Error processing cp_c: Found array with 0 sample(s) (shape=(0, 3)) while a minimum of 1 is required by PolynomialFeatures.
# Error processing cp_d: Found array with 0 sample(s) (shape=(0, 3)) while a minimum of 1 is required by PolynomialFeatures.
#
# Predicted Properties for example composition:
#   Melt(K): 1117.7126
#   Boil(K): 1758.0393
#   rho_a: 2.4326
#   rho_b: 0.0006
#   mu1_a: 0.1292
#   mu1_b: 27773.2246
#   mu2_b: 530.6222
#   mu2_a: 0.0000
#   mu2_c: 32784.2228
#   k_a: 0.9092
#   k_b: -0.0002
#   cp_a: 123.2180
#   cp_b: -0.0692
#
# Model Performance Summary (R2 and MSE):
#
# Target: Melt(K)
#   Linear Regression: R2 = 0.1192, MSE = 22891.8779
#   Ridge Regression: R2 = 0.1141, MSE = 23023.8208
#   Lasso Regression: R2 = 0.1057, MSE = 23241.0499
#   Random Forest: R2 = 0.5200, MSE = 12474.0433
#   Gradient Boosting: R2 = 0.6243, MSE = 9763.6601
#   SVR: R2 = 0.1266, MSE = 22698.5970
#   Neural Network: R2 = 0.0331, MSE = 25128.9366
#
# Target: Boil(K)
#   Linear Regression: R2 = 0.0384, MSE = 829019.2960
#   Ridge Regression: R2 = 0.0000, MSE = 879430.3812
#   Lasso Regression: R2 = 0.0000, MSE = 876030.8872
#   Random Forest: R2 = 0.0000, MSE = 1395536.3587
#   Gradient Boosting: R2 = 0.0000, MSE = 1392297.9000
#   SVR: R2 = 0.0000, MSE = 965486.9500
#   Neural Network: R2 = 0.0000, MSE = 2482388.2056
#
# Target: rho_a
#   Linear Regression: R2 = 0.2788, MSE = 1.1904
#   Ridge Regression: R2 = 0.2873, MSE = 1.1764
#   Lasso Regression: R2 = 0.1158, MSE = 1.4595
#   Random Forest: R2 = 0.7638, MSE = 0.3900
#   Gradient Boosting: R2 = 0.6997, MSE = 0.4957
#   SVR: R2 = 0.5871, MSE = 0.6816
#   Neural Network: R2 = 0.6267, MSE = 0.6162
#
# Target: rho_b
#   Linear Regression: R2 = 0.4964, MSE = 0.0000
#   Ridge Regression: R2 = 0.5002, MSE = 0.0000
#   Lasso Regression: R2 = 0.0000, MSE = 0.0000
#   Random Forest: R2 = 0.7761, MSE = 0.0000
#   Gradient Boosting: R2 = 0.7723, MSE = 0.0000
#   SVR: R2 = 0.0000, MSE = 0.0000
#   Neural Network: R2 = 0.0000, MSE = 0.0003
#
# Target: mu1_a
#   Linear Regression: R2 = 0.0000, MSE = 0.0020
#   Ridge Regression: R2 = 0.0000, MSE = 0.0020
#   Lasso Regression: R2 = 0.0000, MSE = 0.0026
#   Random Forest: R2 = 0.0000, MSE = 0.0016
#   Gradient Boosting: R2 = 0.0000, MSE = 0.0014
#   SVR: R2 = 0.0000, MSE = 0.0016
#   Neural Network: R2 = 0.0000, MSE = 0.0011
#
# Target: mu1_b
#   Linear Regression: R2 = 0.6908, MSE = 36802988.3098
#   Ridge Regression: R2 = 0.6802, MSE = 38068725.6802
#   Lasso Regression: R2 = 0.6894, MSE = 36969197.2213
#   Random Forest: R2 = 0.5573, MSE = 52700873.8741
#   Gradient Boosting: R2 = 0.7051, MSE = 35109955.0246
#   SVR: R2 = 0.0360, MSE = 114752580.1316
#   Neural Network: R2 = 0.0000, MSE = 1360017557.1242
#
# Target: mu2_b
#   Linear Regression: R2 = 0.0829, MSE = 250754.7516
#   Ridge Regression: R2 = 0.1353, MSE = 236451.1571
#   Lasso Regression: R2 = 0.1743, MSE = 225770.6020
#   Random Forest: R2 = 0.0000, MSE = 753947.2418
#   Gradient Boosting: R2 = 0.0000, MSE = 1476145.6374
#   SVR: R2 = 0.1517, MSE = 231966.0514
#   Neural Network: R2 = 0.0000, MSE = 2811353.3854
#
# Target: mu2_a
#   Linear Regression: R2 = 0.0847, MSE = 0.1860
#   Ridge Regression: R2 = 0.0665, MSE = 0.1897
#   Lasso Regression: R2 = 0.0000, MSE = 0.2217
#   Random Forest: R2 = 0.3882, MSE = 0.1243
#   Gradient Boosting: R2 = 0.5646, MSE = 0.0885
#   SVR: R2 = 0.8528, MSE = 0.0299
#   Neural Network: R2 = 0.4363, MSE = 0.1145
#
# Target: mu2_c
#   Linear Regression: R2 = 0.0000, MSE = 32860361119.9197
#   Ridge Regression: R2 = 0.0000, MSE = 23026876879.6038
#   Lasso Regression: R2 = 0.0000, MSE = 32851269387.7916
#   Random Forest: R2 = 0.0000, MSE = 1255479912.7232
#   Gradient Boosting: R2 = 0.0000, MSE = 2479438962.2937
#   SVR: R2 = 0.0000, MSE = 0.0090
#   Neural Network: R2 = 0.0000, MSE = 36.1303
#
# Target: k_a
#   Linear Regression: R2 = nan, MSE = 0.0114
#   Ridge Regression: R2 = nan, MSE = 0.0113
#   Lasso Regression: R2 = nan, MSE = 0.0197
#   Random Forest: R2 = nan, MSE = 0.0552
#   Gradient Boosting: R2 = nan, MSE = 0.0454
#   SVR: R2 = nan, MSE = 0.0078
#   Neural Network: R2 = nan, MSE = 0.0117
#
# Target: k_b
#   Linear Regression: R2 = nan, MSE = 0.0000
#   Ridge Regression: R2 = nan, MSE = 0.0000
#   Lasso Regression: R2 = nan, MSE = 0.0000
#   Random Forest: R2 = nan, MSE = 0.0000
#   Gradient Boosting: R2 = nan, MSE = 0.0000
#   SVR: R2 = nan, MSE = 0.0000
#   Neural Network: R2 = nan, MSE = 0.0032
#
# Target: cp_a
#   Linear Regression: R2 = nan, MSE = 172.4807
#   Ridge Regression: R2 = nan, MSE = 378.5048
#   Lasso Regression: R2 = nan, MSE = 36.4280
#   Random Forest: R2 = nan, MSE = 267.0387
#   Gradient Boosting: R2 = nan, MSE = 460.3188
#   SVR: R2 = nan, MSE = 889.6674
#   Neural Network: R2 = nan, MSE = 970.4387
#
# Target: cp_b
#   Linear Regression: R2 = nan, MSE = 0.0135
#   Ridge Regression: R2 = nan, MSE = 0.0518
#   Lasso Regression: R2 = nan, MSE = 0.0001
#   Random Forest: R2 = nan, MSE = 0.0000
#   Gradient Boosting: R2 = nan, MSE = 0.0007
#   SVR: R2 = nan, MSE = 0.0001
#   Neural Network: R2 = nan, MSE = 1.3694
#
# Plotting R2 scores
#
# Plot actual vs. predicted for best models coefficients
#
# Plot actual vs. predicted for best model physical properties
# Saved: actual_vs_predicted_Density.png (521 points, 137 skipped)
# Saved: actual_vs_predicted_Viscosity_A.png (148 points, 510 skipped)
# Saved: actual_vs_predicted_Thermal_Conductivity.png (9 points, 649 skipped)
# Saved: actual_vs_predicted_Heat_Capacity_of_Liquid.png (19 points, 639 skipped)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys

# Ensure local module path is visible
PROJECT_PATH = os.path.abspath(os.path.join(os.getcwd(), ".."))
print("Adding to sys.path:", PROJECT_PATH)
sys.path.insert(0, PROJECT_PATH)

from processing_mstdb.processor import MSTDBProcessor
from processing_mstdb.resnet_trainer import ResNetMetaTrainer, TARGETS, DERIVED_PROPS

# Step 1: Load and preprocess the data
data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_processed.csv"))
# data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_janz_processed.csv"))
print("Loading data from:", data_path)

processor = MSTDBProcessor.from_csv(data_path)
processor.df.columns = processor.df.columns.str.strip()

composition_type = 'both'

processor.df['Composition'] = processor.df.apply(
    lambda row: processor.compute_composition(row, composition_type=composition_type), axis=1
)

filter_dict = {
    "include": {
        # "elements": ["Na", "Cl"],
        "compounds": ["NaCl", "KCl"]
    }
}
processor = processor.filter_by_components(filter_dict)

# Step 2: Train ResNet+Meta+Physics
trainer = ResNetMetaTrainer(processor.df, TARGETS, DERIVED_PROPS, embedding_method='pca', n_components=10)
trainer.train_base()
trainer.train_meta()
trainer.train_joint()

# Step 3: Predict for an example
example_composition = {'Na': 0.5, 'Cl': 0.5}
predicted_coeffs = trainer.predict(example_composition)
print("\nPredicted coefficients for 50-50 NaCl:")
for k, v in predicted_coeffs.items():
    print(f"{k}: {v:.4f}")

# Step 4: Compute derived properties at 900K
derived_props = trainer.derived(predicted_coeffs, 900)
print("\nDerived properties at 900K:")
for k, v in derived_props.items():
    print(f"{k}: {v:.4f}")

# Step 5: Plotting
print("\nPlotting results...")
plot_dir = "resnet_prediction_plots"
os.makedirs(plot_dir, exist_ok=True)

# Helper to predict batches
def predict_all(X_input):
    import torch
    trainer.base_nets.eval()
    trainer.meta.eval()
    with torch.no_grad():
        xb = torch.tensor(X_input, dtype=torch.float32, device=trainer.device)
        base_out = torch.stack([trainer.base_nets[p](xb) for p in trainer.present_targets], 1)
        pred = (base_out + trainer.meta(base_out)).cpu().numpy()
        return pred * trainer.σ + trainer.μ

# Step 6: Actual vs Predicted - coefficients
for split_name, idx_set in zip(["train", "test"], [trainer.tr_idx, trainer.te_idx]):
    y_true = trainer.y_raw[idx_set]
    y_pred = predict_all(trainer.X_embedded[idx_set])

    for j, target in enumerate(trainer.present_targets):
        mask = y_true[:, j] > 1e-10
        if np.any(mask):
          plt.figure(figsize=(6, 6))
          plt.scatter(y_true[mask, j], y_pred[mask, j], alpha=0.7)
          plt.plot([y_true[mask, j].min(), y_true[mask, j].max()],
                  [y_true[mask, j].min(), y_true[mask, j].max()], 'r--')
          plt.title(f"{target} ({split_name} set)")
          plt.xlabel("Actual")
          plt.ylabel("Predicted")
          plt.grid(True)
          plt.tight_layout()
          fname = f"actual_vs_predicted_coeff_{target}_{split_name}.png"
          plt.savefig(os.path.join(plot_dir, fname))
          plt.close()
          print(f"Saved: {fname}")

# Step 7: Actual vs Predicted - thermophysical properties
def compute_actual_properties_from_coeffs(row, temperature):
    coeff = {col: row.get(col, 0.0) for col in trainer.present_targets}
    return trainer.derived(coeff, temperature)

print("\nPlotting actual vs. predicted thermophysical properties...")

temperature = 900  # Kelvin
properties_to_compare = ["rho", "muA", "muB", "k", "cp"]

for split_name, idx_set in zip(["train", "test"], [trainer.tr_idx, trainer.te_idx]):
    actual_vals_dict = {prop: [] for prop in properties_to_compare}
    predicted_vals_dict = {prop: [] for prop in properties_to_compare}

    for idx in idx_set:
        row = trainer.df.iloc[idx]
        actual_coeffs = {col: row.get(col, 0.0) for col in trainer.present_targets}
        actual_props = trainer.derived(actual_coeffs, temperature)

        pred_coeffs = dict(zip(trainer.present_targets, predict_all(trainer.X_embedded[[idx]])[0]))
        pred_props = trainer.derived(pred_coeffs, temperature)

        for prop in properties_to_compare:
            a = actual_props.get(prop, None)
            p = pred_props.get(prop, None)
            if a is not None and p is not None and a > 1e-6:
                actual_vals_dict[prop].append(a)
                predicted_vals_dict[prop].append(p)

    for prop in properties_to_compare:
        if actual_vals_dict[prop] and predicted_vals_dict[prop]:
            plt.figure(figsize=(6, 6))
            plt.scatter(actual_vals_dict[prop], predicted_vals_dict[prop], alpha=0.7)
            plt.plot([min(actual_vals_dict[prop]), max(actual_vals_dict[prop])],
                     [min(actual_vals_dict[prop]), max(actual_vals_dict[prop])], 'r--')
            plt.title(f"{prop} at {temperature} K ({split_name} set)")
            plt.xlabel("Actual")
            plt.ylabel("Predicted")
            plt.grid(True)
            plt.tight_layout()
            fname = f"actual_vs_predicted_property_{prop}_{split_name}.png"
            plt.savefig(os.path.join(plot_dir, fname))
            plt.close()
            print(f"Saved: {fname}")
        else:
            print(f"Skipped {prop} ({split_name}) — no valid data.")

print("\nAll plots saved in", plot_dir)
# Out:
# Adding to sys.path: /Users/mauriciotano/projects/MoltenSaltPropnet
# Loading data from: /Users/mauriciotano/projects/MoltenSaltPropnet/data/mstdb_processed.csv
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#  • Training base net for Melt(K)
#  ⇢ Early stopping for Melt(K)
#  • Training base net for Boil(K)
#  ⇢ Early stopping for Boil(K)
#  • Training base net for rho_a
#  ⇢ Early stopping for rho_a
#  • Training base net for rho_b
#  ⇢ Early stopping for rho_b
#  • Training base net for mu1_a
#  ⇢ Early stopping for mu1_a
#  • Training base net for mu1_b
#  ⇢ Early stopping for mu1_b
#  • Training base net for mu2_a
#  ⇢ Early stopping for mu2_a
#  • Training base net for mu2_b
#  ⇢ Early stopping for mu2_b
#  • Training base net for mu2_c
#  ⇢ Early stopping for mu2_c
#  • Training base net for k_a
#  ⇢ Early stopping for k_a
#  • Training base net for k_b
#  ⇢ Early stopping for k_b
#  • Training base net for cp_a
#  ⇢ Early stopping for cp_a
#  • Training base net for cp_b
#  ⇢ Early stopping for cp_b
#
# Stage-2: Training meta net with physics regularization...
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   0 | Train: 1.6212 | Val: 0.7490
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   1 | Train: 0.7685 | Val: 0.2091
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   2 | Train: 0.4313 | Val: 0.2518
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   3 | Train: 0.2955 | Val: 0.2384
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   4 | Train: 0.5108 | Val: 0.1875
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   5 | Train: 0.1702 | Val: 0.1811
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   6 | Train: 0.1541 | Val: 0.1736
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   7 | Train: 0.1319 | Val: 0.2042
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   8 | Train: 0.1062 | Val: 0.1882
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch   9 | Train: 0.0800 | Val: 0.1683
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  10 | Train: 0.0847 | Val: 0.1836
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  11 | Train: 0.1075 | Val: 0.1828
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  12 | Train: 0.0845 | Val: 0.2123
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  13 | Train: 0.0897 | Val: 0.1702
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  14 | Train: 0.1012 | Val: 0.1688
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  15 | Train: 0.0652 | Val: 0.1558
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  16 | Train: 0.0687 | Val: 0.1627
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  17 | Train: 0.0764 | Val: 0.1696
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  18 | Train: 0.0729 | Val: 0.1636
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  19 | Train: 0.0877 | Val: 0.1521
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  20 | Train: 0.1009 | Val: 0.1566
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  21 | Train: 0.0611 | Val: 0.1726
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  22 | Train: 0.1060 | Val: 0.1520
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  23 | Train: 0.1123 | Val: 0.1496
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  24 | Train: 0.0688 | Val: 0.1637
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  25 | Train: 0.0798 | Val: 0.1569
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  26 | Train: 0.0654 | Val: 0.1561
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  27 | Train: 0.0733 | Val: 0.1628
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  28 | Train: 0.0673 | Val: 0.1563
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  29 | Train: 0.0869 | Val: 0.1643
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  30 | Train: 0.0700 | Val: 0.1668
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  31 | Train: 0.0795 | Val: 0.1677
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch  32 | Train: 0.0547 | Val: 0.1555
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ...
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 201 | Train: 0.0388 | Val: 0.1443
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 202 | Train: 0.0455 | Val: 0.1441
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 203 | Train: 0.0421 | Val: 0.1409
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 204 | Train: 0.0405 | Val: 0.1470
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 205 | Train: 0.0444 | Val: 0.1476
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 206 | Train: 0.0610 | Val: 0.1447
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 207 | Train: 0.0439 | Val: 0.1443
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 208 | Train: 0.0415 | Val: 0.1462
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 209 | Train: 0.0471 | Val: 0.1435
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 210 | Train: 0.0379 | Val: 0.1408
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Epoch 211 | Train: 0.0463 | Val: 0.1405
#  ⇢ Early stopping
#
# Predicted coefficients for 50-50 NaCl:
# Melt(K): 1252.3596
# Boil(K): 140.1377
# rho_a: 4.4293
# rho_b: -0.0067
# mu1_a: 0.4665
# mu1_b: -70015.7969
# mu2_a: 0.6887
# mu2_b: 1063.9648
# mu2_c: -1.7474
# k_a: -0.2038
# k_b: 0.0000
# cp_a: -35.2538
# cp_b: 0.0013
#
# Derived properties at 900K:
# rho: 10.4944
# muA: 0.0000
# muB: 74.2774
# k: -0.1679
#
# Plotting results...
# Saved: actual_vs_predicted_coeff_Melt(K)_train.png
# Saved: actual_vs_predicted_coeff_Boil(K)_train.png
# Saved: actual_vs_predicted_coeff_rho_a_train.png
# Saved: actual_vs_predicted_coeff_rho_b_train.png
# Saved: actual_vs_predicted_coeff_mu1_a_train.png
# Saved: actual_vs_predicted_coeff_mu1_b_train.png
# Saved: actual_vs_predicted_coeff_mu2_b_train.png
# Saved: actual_vs_predicted_coeff_k_a_train.png
# Saved: actual_vs_predicted_coeff_cp_a_train.png
# Saved: actual_vs_predicted_coeff_Melt(K)_test.png
# Saved: actual_vs_predicted_coeff_Boil(K)_test.png
# Saved: actual_vs_predicted_coeff_rho_a_test.png
# Saved: actual_vs_predicted_coeff_rho_b_test.png
# Saved: actual_vs_predicted_coeff_mu1_a_test.png
# Saved: actual_vs_predicted_coeff_mu1_b_test.png
# Saved: actual_vs_predicted_coeff_mu2_b_test.png
# Saved: actual_vs_predicted_coeff_k_a_test.png
# Saved: actual_vs_predicted_coeff_cp_a_test.png
# Saved: actual_vs_predicted_coeff_cp_b_test.png
#
# Plotting actual vs. predicted thermophysical properties...
# Saved: actual_vs_predicted_property_rho_train.png
# Saved: actual_vs_predicted_property_muA_train.png
# Saved: actual_vs_predicted_property_muB_train.png
# Saved: actual_vs_predicted_property_k_train.png
# Skipped cp (train) — no valid data.
# Saved: actual_vs_predicted_property_rho_test.png
# Saved: actual_vs_predicted_property_muA_test.png
# Saved: actual_vs_predicted_property_muB_test.png
# Saved: actual_vs_predicted_property_k_test.png
# Skipped cp (test) — no valid data.
#
# All plots saved in resnet_prediction_plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys

# Ensure local module path is visible
PROJECT_PATH = os.path.abspath(os.path.join(os.getcwd(), ".."))
print("Adding to sys.path:", PROJECT_PATH)
sys.path.insert(0, PROJECT_PATH)

from processing_mstdb.processor import MSTDBProcessor
from processing_mstdb.kan_trainer import KANMetaTrainer, TARGETS, DERIVED_PROPS

# Step 1: Load and preprocess the data
data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_processed.csv"))
# data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_janz_processed.csv"))
print("Loading data from:", data_path)

processor = MSTDBProcessor.from_csv(data_path)
processor.df.columns = processor.df.columns.str.strip()

composition_type = 'both'

processor.df['Composition'] = processor.df.apply(
    lambda row: processor.compute_composition(row, composition_type=composition_type), axis=1
)

filter_dict = {
    "include": {
        # "elements": ["Na", "Cl"],
        "compounds": ["NaCl", "KCl"]
    }
}
processor = processor.filter_by_components(filter_dict)

# Step 2: Train KAN+Meta+Physics
trainer = KANMetaTrainer(processor.df, TARGETS, DERIVED_PROPS,  embedding_method='pca', n_components=10)
trainer.train_base()
trainer.train_meta()
trainer.train_joint()

# Step 3: Predict for an example
example_composition = {'Na': 0.5, 'Cl': 0.5}
predicted_coeffs = trainer.predict(example_composition)
print("\nPredicted coefficients for 50-50 NaCl:")
for k, v in predicted_coeffs.items():
    print(f"{k}: {v:.4f}")

# Step 4: Compute derived properties at 900K
derived_props = trainer.derived(predicted_coeffs, 900)
print("\nDerived properties at 900K:")
for k, v in derived_props.items():
    print(f"{k}: {v:.4f}")

# Step 5: Plotting
print("\nPlotting results...")
plot_dir = "kan_prediction_plots"
os.makedirs(plot_dir, exist_ok=True)

# Helper to predict batches
def predict_all(X_input):
    import torch
    trainer.base_nets.eval()
    trainer.meta.eval()
    with torch.no_grad():
        xb = torch.tensor(X_input, dtype=torch.float32, device=trainer.device)
        base_out = torch.stack([trainer.base_nets[p](xb) for p in trainer.present_targets], 1)
        pred = (base_out + trainer.meta(base_out)).cpu().numpy()
        return pred * trainer.σ + trainer.μ

# Step 6: Actual vs Predicted - coefficients
for split_name, idx_set in zip(["train", "test"], [trainer.tr_idx, trainer.te_idx]):
    y_true = trainer.y_raw[idx_set]
    y_pred = predict_all(trainer.X_embedded[idx_set])

    for j, target in enumerate(trainer.present_targets):
        mask = y_true[:, j] > 1e-10
        if np.any(mask):
            plt.figure(figsize=(6, 6))
            plt.scatter(y_true[mask, j], y_pred[mask, j], alpha=0.7)
            plt.plot([y_true[mask, j].min(), y_true[mask, j].max()],
                    [y_true[mask, j].min(), y_true[mask, j].max()], 'r--')
            plt.title(f"{target} ({split_name} set)")
            plt.xlabel("Actual")
            plt.ylabel("Predicted")
            plt.grid(True)
            plt.tight_layout()
            fname = f"actual_vs_predicted_coeff_{target}_{split_name}.png"
            plt.savefig(os.path.join(plot_dir, fname))
            plt.close()
            print(f"Saved: {fname}")

# Step 7: Actual vs Predicted - thermophysical properties
def compute_actual_properties_from_coeffs(row, temperature):
    coeff = {col: row.get(col, 0.0) for col in trainer.present_targets}
    return trainer.derived(coeff, temperature)

print("\nPlotting actual vs. predicted thermophysical properties...")

temperature = 900  # Kelvin
properties_to_compare = ["rho", "muA", "muB", "k", "cp"]

for split_name, idx_set in zip(["train", "test"], [trainer.tr_idx, trainer.te_idx]):
    actual_vals_dict = {prop: [] for prop in properties_to_compare}
    predicted_vals_dict = {prop: [] for prop in properties_to_compare}

    for idx in idx_set:
        row = trainer.df.iloc[idx]
        actual_coeffs = {col: row.get(col, 0.0) for col in trainer.present_targets}
        actual_props = trainer.derived(actual_coeffs, temperature)

        pred_coeffs = dict(zip(trainer.present_targets, predict_all(trainer.X_embedded[[idx]])[0]))
        pred_props = trainer.derived(pred_coeffs, temperature)

        for prop in properties_to_compare:
            a = actual_props.get(prop, None)
            p = pred_props.get(prop, None)
            if a is not None and p is not None and a > 1e-6:
                actual_vals_dict[prop].append(a)
                predicted_vals_dict[prop].append(p)

    for prop in properties_to_compare:
        if actual_vals_dict[prop] and predicted_vals_dict[prop]:
            plt.figure(figsize=(6, 6))
            plt.scatter(actual_vals_dict[prop], predicted_vals_dict[prop], alpha=0.7)
            plt.plot([min(actual_vals_dict[prop]), max(actual_vals_dict[prop])],
                     [min(actual_vals_dict[prop]), max(actual_vals_dict[prop])], 'r--')
            plt.title(f"{prop} at {temperature} K ({split_name} set)")
            plt.xlabel("Actual")
            plt.ylabel("Predicted")
            plt.grid(True)
            plt.tight_layout()
            fname = f"actual_vs_predicted_property_{prop}_{split_name}.png"
            plt.savefig(os.path.join(plot_dir, fname))
            plt.close()
            print(f"Saved: {fname}")
        else:
            print(f"Skipped {prop} ({split_name}) — no valid data.")

print("\nAll plots saved in", plot_dir)
# Out:
# Adding to sys.path: /Users/mauriciotano/projects/MoltenSaltPropnet
# Loading data from: /Users/mauriciotano/projects/MoltenSaltPropnet/data/mstdb_processed.csv
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#
# Stage-1: Training base KANs...
#  • Training base net for Melt(K)
#  ⇢ Early stopping for Melt(K)
#  • Training base net for Boil(K)
#  ⇢ Early stopping for Boil(K)
#  • Training base net for rho_a
#  ⇢ Early stopping for rho_a
#  • Training base net for rho_b
#  ⇢ Early stopping for rho_b
#  • Training base net for mu1_a
#  ⇢ Early stopping for mu1_a
#  • Training base net for mu1_b
#  ⇢ Early stopping for mu1_b
#  • Training base net for mu2_a
#  ⇢ Early stopping for mu2_a
#  • Training base net for mu2_b
#  ⇢ Early stopping for mu2_b
#  • Training base net for mu2_c
#  ⇢ Early stopping for mu2_c
#  • Training base net for k_a
#  ⇢ Early stopping for k_a
#  • Training base net for k_b
#  ⇢ Early stopping for k_b
#  • Training base net for cp_a
#  ⇢ Early stopping for cp_a
#  • Training base net for cp_b
#  ⇢ Early stopping for cp_b
#
# Stage-2: Training meta net with physics regularization...
# Epoch   0 | Train: 0.5660 | Val: 0.1659
# Epoch   1 | Train: 0.2906 | Val: 0.1735
# Epoch   2 | Train: 0.2621 | Val: 0.1586
# Epoch   3 | Train: 0.2508 | Val: 0.1543
# Epoch   4 | Train: 0.2398 | Val: 0.1498
# Epoch   5 | Train: 0.2534 | Val: 0.1465
# Epoch   6 | Train: 0.2279 | Val: 0.1474
# Epoch   7 | Train: 0.2086 | Val: 0.1539
# Epoch   8 | Train: 0.1986 | Val: 0.1549
# Epoch   9 | Train: 0.1925 | Val: 0.1523
# Epoch  10 | Train: 0.2036 | Val: 0.1508
# Epoch  11 | Train: 0.1829 | Val: 0.1511
# Epoch  12 | Train: 0.1977 | Val: 0.1506
# Epoch  13 | Train: 0.2058 | Val: 0.1521
# Epoch  14 | Train: 0.1774 | Val: 0.1544
# Epoch  15 | Train: 0.1507 | Val: 0.1528
# Epoch  16 | Train: 0.1431 | Val: 0.1503
# Epoch  17 | Train: 0.1600 | Val: 0.1550
# Epoch  18 | Train: 0.1397 | Val: 0.1551
# Epoch  19 | Train: 0.1249 | Val: 0.1498
# Epoch  20 | Train: 0.1197 | Val: 0.1486
# Epoch  21 | Train: 0.1542 | Val: 0.1505
# Epoch  22 | Train: 0.1216 | Val: 0.1498
# Epoch  23 | Train: 0.1083 | Val: 0.1513
# Epoch  24 | Train: 0.1342 | Val: 0.1545
# Epoch  25 | Train: 0.1211 | Val: 0.1531
# Epoch  26 | Train: 0.0994 | Val: 0.1547
# Epoch  27 | Train: 0.1779 | Val: 0.1505
# Epoch  28 | Train: 0.0951 | Val: 0.1507
# Epoch  29 | Train: 0.0918 | Val: 0.1529
# Epoch  30 | Train: 0.0880 | Val: 0.1555
# Epoch  31 | Train: 1.1263 | Val: 0.1514
# Epoch  32 | Train: 0.0779 | Val: 0.1518
# Epoch  33 | Train: 0.0754 | Val: 0.1519
# Epoch  34 | Train: 0.0743 | Val: 0.1509
# Epoch  35 | Train: 0.0823 | Val: 0.1533
# Epoch  36 | Train: 0.0653 | Val: 0.1489
# Epoch  37 | Train: 0.1042 | Val: 0.1468
# Epoch  38 | Train: 0.0624 | Val: 0.1482
# Epoch  39 | Train: 0.0624 | Val: 0.1472
# Epoch  40 | Train: 0.0586 | Val: 0.1483
#  ⇢ Early stopping
#
# Joint Training: Optimizing base and meta KAN networks together...
# Epoch   0 | Train Loss: 0.2443 | Val Loss: 0.1574
# Epoch   1 | Train Loss: 0.2083 | Val Loss: 0.1457
# Epoch   2 | Train Loss: 0.1968 | Val Loss: 0.1476
# Epoch   3 | Train Loss: 0.1911 | Val Loss: 0.1555
# Epoch   4 | Train Loss: 0.1832 | Val Loss: 0.1499
# Epoch   5 | Train Loss: 0.1689 | Val Loss: 0.1498
# Epoch   6 | Train Loss: 0.1662 | Val Loss: 0.1495
# Epoch   7 | Train Loss: 0.1517 | Val Loss: 0.1518
# Epoch   8 | Train Loss: 0.1421 | Val Loss: 0.1520
# Epoch   9 | Train Loss: 0.1431 | Val Loss: 0.1472
# Epoch  10 | Train Loss: 0.2168 | Val Loss: 0.1449
# Epoch  11 | Train Loss: 0.1273 | Val Loss: 0.1497
# Epoch  12 | Train Loss: 0.1195 | Val Loss: 0.1577
# Epoch  13 | Train Loss: 0.1272 | Val Loss: 0.1541
# Epoch  14 | Train Loss: 0.1080 | Val Loss: 0.1500
# Epoch  15 | Train Loss: 0.1130 | Val Loss: 0.1487
# Epoch  16 | Train Loss: 0.1030 | Val Loss: 0.1532
# Epoch  17 | Train Loss: 0.1118 | Val Loss: 0.1562
# Epoch  18 | Train Loss: 0.0993 | Val Loss: 0.1515
# Epoch  19 | Train Loss: 0.1000 | Val Loss: 0.1517
# Epoch  20 | Train Loss: 0.0932 | Val Loss: 0.1455
# Epoch  21 | Train Loss: 0.0908 | Val Loss: 0.1522
# Epoch  22 | Train Loss: 0.0871 | Val Loss: 0.1511
# Epoch  23 | Train Loss: 0.1468 | Val Loss: 0.1516
# Epoch  24 | Train Loss: 0.0839 | Val Loss: 0.1476
# Epoch  25 | Train Loss: 0.0756 | Val Loss: 0.1477
# Epoch  26 | Train Loss: 0.0755 | Val Loss: 0.1473
# Epoch  27 | Train Loss: 0.0698 | Val Loss: 0.1462
# Epoch  28 | Train Loss: 0.0757 | Val Loss: 0.1485
# Epoch  29 | Train Loss: 0.0639 | Val Loss: 0.1494
# Epoch  30 | Train Loss: 0.0651 | Val Loss: 0.1471
# Epoch  31 | Train Loss: 0.0610 | Val Loss: 0.1473
# Epoch  32 | Train Loss: 0.0594 | Val Loss: 0.1455
# Epoch  33 | Train Loss: 0.0612 | Val Loss: 0.1460
# Epoch  34 | Train Loss: 0.0543 | Val Loss: 0.1487
# Epoch  35 | Train Loss: 0.0584 | Val Loss: 0.1509
# Epoch  36 | Train Loss: 0.0558 | Val Loss: 0.1486
# Epoch  37 | Train Loss: 0.0494 | Val Loss: 0.1443
# Epoch  38 | Train Loss: 0.0499 | Val Loss: 0.1509
# Epoch  39 | Train Loss: 0.0509 | Val Loss: 0.1495
# Epoch  40 | Train Loss: 0.0566 | Val Loss: 0.1504
# Epoch  41 | Train Loss: 0.0490 | Val Loss: 0.1498
# Epoch  42 | Train Loss: 0.0531 | Val Loss: 0.1508
# Epoch  43 | Train Loss: 0.0443 | Val Loss: 0.1553
# Epoch  44 | Train Loss: 0.0431 | Val Loss: 0.1523
# Epoch  45 | Train Loss: 0.0387 | Val Loss: 0.1484
# Epoch  46 | Train Loss: 0.0403 | Val Loss: 0.1473
# Epoch  47 | Train Loss: 0.0388 | Val Loss: 0.1475
# Epoch  48 | Train Loss: 0.0496 | Val Loss: 0.1529
# Epoch  49 | Train Loss: 0.0389 | Val Loss: 0.1629
# Epoch  50 | Train Loss: 0.0376 | Val Loss: 0.1500
# Epoch  51 | Train Loss: 0.0382 | Val Loss: 0.1455
# Epoch  52 | Train Loss: 0.0385 | Val Loss: 0.1496
# Epoch  53 | Train Loss: 0.0353 | Val Loss: 0.1508
# Epoch  54 | Train Loss: 0.0681 | Val Loss: 0.1535
# Epoch  55 | Train Loss: 0.0322 | Val Loss: 0.1510
# Epoch  56 | Train Loss: 0.0996 | Val Loss: 0.1531
# Epoch  57 | Train Loss: 0.0343 | Val Loss: 0.1538
# Epoch  58 | Train Loss: 0.0350 | Val Loss: 0.1526
# Epoch  59 | Train Loss: 0.0407 | Val Loss: 0.1473
# Epoch  60 | Train Loss: 0.0303 | Val Loss: 0.1459
# Epoch  61 | Train Loss: 0.0307 | Val Loss: 0.1492
# Epoch  62 | Train Loss: 0.0320 | Val Loss: 0.1512
# Epoch  63 | Train Loss: 0.0334 | Val Loss: 0.1496
# Epoch  64 | Train Loss: 0.0305 | Val Loss: 0.1544
# Epoch  65 | Train Loss: 0.0326 | Val Loss: 0.1563
# Epoch  66 | Train Loss: 0.0353 | Val Loss: 0.1560
# Epoch  67 | Train Loss: 0.0350 | Val Loss: 0.1510
# Epoch  68 | Train Loss: 0.0435 | Val Loss: 0.1516
# Epoch  69 | Train Loss: 0.0300 | Val Loss: 0.1514
# Epoch  70 | Train Loss: 0.0316 | Val Loss: 0.1600
# Epoch  71 | Train Loss: 0.0310 | Val Loss: 0.1544
# Epoch  72 | Train Loss: 0.0356 | Val Loss: 0.1543
# Epoch  73 | Train Loss: 0.0301 | Val Loss: 0.1518
# Epoch  74 | Train Loss: 0.0280 | Val Loss: 0.1566
# Epoch  75 | Train Loss: 0.0304 | Val Loss: 0.1566
# Epoch  76 | Train Loss: 0.0272 | Val Loss: 0.1568
# Epoch  77 | Train Loss: 0.0286 | Val Loss: 0.1536
#  ⇢ Early stopping triggered
#
# Predicted coefficients for 50-50 NaCl:
# Melt(K): 3396.6787
# Boil(K): 200.1307
# rho_a: 17.9718
# rho_b: 0.0005
# mu1_a: 0.4746
# mu1_b: -118341.5859
# mu2_a: 1.2630
# mu2_b: 2034.2340
# mu2_c: -1.7457
# k_a: 0.0702
# k_b: 0.0000
# cp_a: 4.8111
# cp_b: -0.0032
#
# Derived properties at 900K:
# rho: 17.5478
# muA: 0.0000
# muB: 3335.9276
# k: 0.0736
#
# Plotting results...
# Saved: actual_vs_predicted_coeff_Melt(K)_train.png
# Saved: actual_vs_predicted_coeff_Boil(K)_train.png
# Saved: actual_vs_predicted_coeff_rho_a_train.png
# Saved: actual_vs_predicted_coeff_rho_b_train.png
# Saved: actual_vs_predicted_coeff_mu1_a_train.png
# Saved: actual_vs_predicted_coeff_mu1_b_train.png
# Saved: actual_vs_predicted_coeff_mu2_b_train.png
# Saved: actual_vs_predicted_coeff_k_a_train.png
# Saved: actual_vs_predicted_coeff_cp_a_train.png
# Saved: actual_vs_predicted_coeff_Melt(K)_test.png
# Saved: actual_vs_predicted_coeff_Boil(K)_test.png
# Saved: actual_vs_predicted_coeff_rho_a_test.png
# Saved: actual_vs_predicted_coeff_rho_b_test.png
# Saved: actual_vs_predicted_coeff_mu1_a_test.png
# Saved: actual_vs_predicted_coeff_mu1_b_test.png
# Saved: actual_vs_predicted_coeff_mu2_b_test.png
# Saved: actual_vs_predicted_coeff_k_a_test.png
# Saved: actual_vs_predicted_coeff_cp_a_test.png
# Saved: actual_vs_predicted_coeff_cp_b_test.png
#
# Plotting actual vs. predicted thermophysical properties...
# Saved: actual_vs_predicted_property_rho_train.png
# Saved: actual_vs_predicted_property_muA_train.png
# Saved: actual_vs_predicted_property_muB_train.png
# Saved: actual_vs_predicted_property_k_train.png
# Skipped cp (train) — no valid data.
# Saved: actual_vs_predicted_property_rho_test.png
# Saved: actual_vs_predicted_property_muA_test.png
# Saved: actual_vs_predicted_property_muB_test.png
# Saved: actual_vs_predicted_property_k_test.png
# Skipped cp (test) — no valid data.
#
# All plots saved in kan_prediction_plots

# %%
"""
train_and_predict_snn.py  —  end-to-end smoke-test for SNNMetaTrainer
--------------------------------------------------------------------
✓ trains base SNNs
✓ trains meta network with physics regularisation
✓ predicts coefficients & derived props for 50-50 NaCl
✓ makes parity plots for train / test splits (coeffs + thermo-props)
"""
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

# ────────────────────────────────────────────────────────────────
#  Make local package importable
# ────────────────────────────────────────────────────────────────
PROJECT_PATH = os.path.abspath(os.path.join(os.getcwd(), ".."))
print("Adding to sys.path:", PROJECT_PATH)
sys.path.insert(0, PROJECT_PATH)

from processing_mstdb.processor import MSTDBProcessor
from processing_mstdb.snn_trainer  import SNNMetaTrainer, TARGETS, DERIVED_PROPS

# ────────────────────────────────────────────────────────────────
#  1. Load & preprocess database
# ────────────────────────────────────────────────────────────────
data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_processed.csv"))
# data_path = os.path.abspath(os.path.join(PROJECT_PATH, "data/mstdb_janz_processed.csv"))
print("Loading data from:", data_path)

processor = MSTDBProcessor.from_csv(data_path)
processor.df.columns = processor.df.columns.str.strip() # remove trailing white spaces

composition_type = 'both'

processor.df['Composition'] = processor.df.apply(
    lambda row: processor.compute_composition(row, composition_type=composition_type), axis=1
)

filter_dict = {
    "include": {
        # "elements": ["Na", "Cl"],
        "compounds": ["NaCl", "KCl"]
    }
}
processor = processor.filter_by_components(filter_dict)

# ────────────────────────────────────────────────────────────────
#  2. Train SNN + meta + physics regularisation
# ────────────────────────────────────────────────────────────────
trainer = SNNMetaTrainer(processor.df, TARGETS, DERIVED_PROPS, embedding_method='pca', n_components=10)
trainer.train_base()
trainer.train_meta()
trainer.train_joint()

# switch all nets to evaluation mode once
for net in trainer.base_nets.values():
    net.eval()
trainer.meta.eval()

# ────────────────────────────────────────────────────────────────
#  3. Quick demo prediction
# ────────────────────────────────────────────────────────────────
example = {"Na": 0.5, "Cl": 0.5}
coeff = trainer.predict(example)

print("\nPredicted coefficients for 50-50 NaCl:")
for k, v in coeff.items():
    print(f"{k:7s}: {v:11.4f}")

print("\nDerived properties at 900 K:")
derived = trainer.derived(coeff, 900)
for k, v in derived.items():
    print(f"{k:4s}: {v:11.4f}")

# ────────────────────────────────────────────────────────────────
#  4. Helper: batch prediction (physical units)
# ────────────────────────────────────────────────────────────────
def predict_all(X_input: np.ndarray) -> np.ndarray:
    xb = torch.tensor(X_input, dtype=torch.float32, device=trainer.device)
    with torch.no_grad():
        # concatenate → shape (B,14)  (stack would give (B,14,1))
        base_std = torch.cat([trainer.base_nets[p](xb)
                              for p in trainer.present_targets], dim=1)
        pred_std = base_std + trainer.meta(base_std)
    return pred_std.cpu().numpy() * trainer.σ + trainer.μ   # back to physical units

# ────────────────────────────────────────────────────────────────
#  5. Parity plots — coefficients
# ────────────────────────────────────────────────────────────────
print("\nPlotting results …")
plot_dir = "snn_prediction_plots"
os.makedirs(plot_dir, exist_ok=True)

for split, idx_set in zip(["train", "test"], [trainer.tr_idx, trainer.te_idx]):

    y_true = trainer.y_raw[idx_set]
    y_pred = predict_all(trainer.X_embedded[idx_set])

    for j, tgt in enumerate(trainer.present_targets):
        mask = y_true[:, j] > 1e-10
        if np.any(mask):
            plt.figure(figsize=(6, 6))
            plt.scatter(y_true[mask, j], y_pred[mask, j], alpha=0.7)
            lims = [y_true[mask, j].min(), y_true[mask, j].max()]
            plt.plot(lims, lims, "r--")
            plt.title(f"{tgt} ({split} set)")
            plt.xlabel("Actual"); plt.ylabel("Predicted"); plt.grid(True)
            plt.tight_layout()
            fname = f"actual_vs_predicted_coeff_{tgt}_{split}.png"
            plt.savefig(os.path.join(plot_dir, fname))
            plt.close()
            print(f"Saved: {fname}")

# ────────────────────────────────────────────────────────────────
#  6. Parity plots — derived thermo-physical properties
# ────────────────────────────────────────────────────────────────
print("\nPlotting actual vs. predicted thermo-physical properties …")

T_plot  = 900                                     # K
props   = ["rho", "muA", "muB", "k", "cp"]

for split, idx_set in zip(["train", "test"], [trainer.tr_idx, trainer.te_idx]):

    actual, pred = {p: [] for p in props}, {p: [] for p in props}

    for idx in idx_set:
        # ground-truth coefficients → properties
        row_coeff = {c: trainer.df.iloc[idx][c] for c in trainer.present_targets}
        a_props   = trainer.derived(row_coeff, T_plot)

        # model coefficients → properties
        m_coeff   = dict(zip(trainer.present_targets,
                             predict_all(trainer.X_embedded[[idx]])[0]))
        p_props   = trainer.derived(m_coeff, T_plot)

        for p in props:
            a = a_props.get(p);  pr = p_props.get(p)
            if a is not None and pr is not None and a > 1e-6:
                actual[p].append(a); pred[p].append(pr)

    for p in props:
        if actual[p]:
            plt.figure(figsize=(6, 6))
            plt.scatter(actual[p], pred[p], alpha=0.7)
            lims = [min(actual[p]), max(actual[p])]
            plt.plot(lims, lims, "r--")
            plt.title(f"{p} at {T_plot} K ({split} set)")
            plt.xlabel("Actual"); plt.ylabel("Predicted"); plt.grid(True)
            plt.tight_layout()
            fname = f"actual_vs_predicted_property_{p}_{split}.png"
            plt.savefig(os.path.join(plot_dir, fname))
            plt.close()
            print(f"Saved: {fname}")
        else:
            print(f"Skipped {p} ({split}) — not enough data")

print("\nAll plots saved in", plot_dir)
# Out:
# Adding to sys.path: /Users/mauriciotano/projects/MoltenSaltPropnet
# Loading data from: /Users/mauriciotano/projects/MoltenSaltPropnet/data/mstdb_processed.csv
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#  • Training base net for Melt(K)
#  • Training base net for Boil(K)
#  ⇢ Early stopping for Boil(K)
#  • Training base net for rho_a
#  ⇢ Early stopping for rho_a
#  • Training base net for rho_b
#  ⇢ Early stopping for rho_b
#  • Training base net for mu1_a
#  • Training base net for mu1_b
#  ⇢ Early stopping for mu1_b
#  • Training base net for mu2_a
#  • Training base net for mu2_b
#  • Training base net for mu2_c
#  ⇢ Early stopping for mu2_c
#  • Training base net for k_a
#  ⇢ Early stopping for k_a
#  • Training base net for k_b
#  ⇢ Early stopping for k_b
#  • Training base net for cp_a
#  ⇢ Early stopping for cp_a
#  • Training base net for cp_b
#  ⇢ Early stopping for cp_b
#
# Stage-2: Training meta net with physics regularization…
# Epoch   0 | train 0.4129 | val 0.1921
# Epoch   1 | train 0.3570 | val 0.1701
# Epoch   2 | train 0.3355 | val 0.1668
# Epoch   3 | train 0.3279 | val 0.1598
# Epoch   4 | train 0.3081 | val 0.1563
# Epoch   5 | train 0.2948 | val 0.1557
# Epoch   6 | train 0.3144 | val 0.1551
# Epoch   7 | train 0.5323 | val 0.1553
# Epoch   8 | train 0.2734 | val 0.1574
# Epoch   9 | train 0.2750 | val 0.1619
# Epoch  10 | train 0.2753 | val 0.1607
# Epoch  11 | train 0.2682 | val 0.1627
# Epoch  12 | train 0.2572 | val 0.1630
# Epoch  13 | train 0.2514 | val 0.1604
# Epoch  14 | train 0.2483 | val 0.1586
# Epoch  15 | train 0.2561 | val 0.1578
# Epoch  16 | train 0.2506 | val 0.1567
# Epoch  17 | train 0.2414 | val 0.1575
# Epoch  18 | train 0.2367 | val 0.1602
# Epoch  19 | train 0.2134 | val 0.1607
# Epoch  20 | train 0.2139 | val 0.1608
# Epoch  21 | train 0.2025 | val 0.1575
# Epoch  22 | train 0.2018 | val 0.1582
# Epoch  23 | train 0.2530 | val 0.1614
# Epoch  24 | train 0.1901 | val 0.1615
# Epoch  25 | train 0.1741 | val 0.1632
# Epoch  26 | train 0.1773 | val 0.1622
# Epoch  27 | train 0.1704 | val 0.1632
# Epoch  28 | train 0.1611 | val 0.1657
# Epoch  29 | train 0.1532 | val 0.1647
# Epoch  30 | train 0.1794 | val 0.1652
# Epoch  31 | train 0.1453 | val 0.1659
# Epoch  32 | train 0.1464 | val 0.1655
# Epoch  33 | train 0.1429 | val 0.1641
# Epoch  34 | train 0.1387 | val 0.1628
# Epoch  35 | train 0.1245 | val 0.1643
# Epoch  36 | train 0.1496 | val 0.1660
# Epoch  37 | train 0.1196 | val 0.1619
# Epoch  38 | train 0.1110 | val 0.1598
# Epoch  39 | train 0.1132 | val 0.1613
# Epoch  40 | train 0.1046 | val 0.1613
# Epoch  41 | train 0.0981 | val 0.1674
# Epoch  42 | train 0.1025 | val 0.1643
# Epoch  43 | train 0.0977 | val 0.1633
# Epoch  44 | train 0.0882 | val 0.1622
# Epoch  45 | train 0.0851 | val 0.1647
# Epoch  46 | train 0.0833 | val 0.1625
# Epoch  47 | train 0.0806 | val 0.1615
# Epoch  48 | train 0.0759 | val 0.1685
# Epoch  49 | train 0.0723 | val 0.1647
# Epoch  50 | train 0.0710 | val 0.1626
# Epoch  51 | train 0.0647 | val 0.1612
# Epoch  52 | train 0.0748 | val 0.1627
# Epoch  53 | train 0.0865 | val 0.1637
# Epoch  54 | train 0.0573 | val 0.1588
# Epoch  55 | train 0.0525 | val 0.1633
# Epoch  56 | train 0.0528 | val 0.1608
# Epoch  57 | train 0.0556 | val 0.1612
# Epoch  58 | train 0.0535 | val 0.1654
# Epoch  59 | train 0.0444 | val 0.1618
# Epoch  60 | train 0.0525 | val 0.1587
# Epoch  61 | train 0.0424 | val 0.1640
# Epoch  62 | train 0.0380 | val 0.1627
# Epoch  63 | train 0.0375 | val 0.1658
# Epoch  64 | train 0.0372 | val 0.1654
# Epoch  65 | train 0.0400 | val 0.1700
# Epoch  66 | train 0.0345 | val 0.1692
# Epoch  67 | train 0.0339 | val 0.1678
# Epoch  68 | train 0.0396 | val 0.1643
# Epoch  69 | train 0.0328 | val 0.1652
# Epoch  70 | train 0.0329 | val 0.1635
# Epoch  71 | train 0.0321 | val 0.1634
# Epoch  72 | train 0.0294 | val 0.1635
# Epoch  73 | train 0.0283 | val 0.1623
# Epoch  74 | train 0.0296 | val 0.1606
# Epoch  75 | train 0.0289 | val 0.1619
# Epoch  76 | train 0.0307 | val 0.1642
# Epoch  77 | train 0.0269 | val 0.1619
# Epoch  78 | train 0.0430 | val 0.1642
# Epoch  79 | train 0.0278 | val 0.1664
# Epoch  80 | train 0.0402 | val 0.1651
# Epoch  81 | train 0.0326 | val 0.1632
# Epoch  82 | train 0.0296 | val 0.1644
# Epoch  83 | train 0.0268 | val 0.1678
# Epoch  84 | train 0.0273 | val 0.1652
# Epoch  85 | train 0.0322 | val 0.1625
# Epoch  86 | train 0.0315 | val 0.1636
# Epoch  87 | train 0.0251 | val 0.1624
# Epoch  88 | train 0.0258 | val 0.1629
# Epoch  89 | train 0.0268 | val 0.1657
# Epoch  90 | train 0.0405 | val 0.1657
# Epoch  91 | train 0.0267 | val 0.1659
# Epoch  92 | train 0.0368 | val 0.1667
# Epoch  93 | train 0.0276 | val 0.1674
# Epoch  94 | train 0.0319 | val 0.1663
# Epoch  95 | train 0.0283 | val 0.1665
# Epoch  96 | train 0.0293 | val 0.1718
# Epoch  97 | train 0.0271 | val 0.1678
# Epoch  98 | train 0.0263 | val 0.1638
# Epoch  99 | train 0.0641 | val 0.1635
# Epoch 100 | train 0.0241 | val 0.1641
# Epoch 101 | train 0.0260 | val 0.1606
# Epoch 102 | train 0.0241 | val 0.1648
# Epoch 103 | train 0.0290 | val 0.1656
# Epoch 104 | train 0.0260 | val 0.1655
# Epoch 105 | train 0.0247 | val 0.1667
# Epoch 106 | train 0.0249 | val 0.1635
#  ⇢ Early stopping meta
#
# Joint Training: Optimizing base and meta SNN networks together...
# Epoch   0 | Train: 0.3102 | Val: 0.1793
# Epoch   1 | Train: 0.2807 | Val: 0.1749
# Epoch   2 | Train: 0.2831 | Val: 0.1684
# Epoch   3 | Train: 0.2705 | Val: 0.1706
# Epoch   4 | Train: 0.2971 | Val: 0.1745
# Epoch   5 | Train: 0.2559 | Val: 0.1777
# Epoch   6 | Train: 0.2596 | Val: 0.1776
# Epoch   7 | Train: 0.2393 | Val: 0.1758
# Epoch   8 | Train: 0.4784 | Val: 0.1740
# Epoch   9 | Train: 0.2287 | Val: 0.1752
# Epoch  10 | Train: 0.2291 | Val: 0.1779
# Epoch  11 | Train: 0.2104 | Val: 0.1760
# Epoch  12 | Train: 0.2461 | Val: 0.1750
# Epoch  13 | Train: 0.2081 | Val: 0.1784
# Epoch  14 | Train: 0.1852 | Val: 0.1790
# Epoch  15 | Train: 0.1874 | Val: 0.1809
# Epoch  16 | Train: 0.1781 | Val: 0.1814
# Epoch  17 | Train: 0.1848 | Val: 0.1786
# Epoch  18 | Train: 0.1936 | Val: 0.1780
# Epoch  19 | Train: 0.1829 | Val: 0.1773
# Epoch  20 | Train: 0.1531 | Val: 0.1879
# Epoch  21 | Train: 0.1501 | Val: 0.1792
# Epoch  22 | Train: 0.1423 | Val: 0.1757
# Epoch  23 | Train: 0.1692 | Val: 0.1784
# Epoch  24 | Train: 0.1363 | Val: 0.1841
# Epoch  25 | Train: 0.1212 | Val: 0.1839
# Epoch  26 | Train: 0.1152 | Val: 0.1802
# Epoch  27 | Train: 1.5584 | Val: 0.1829
# Epoch  28 | Train: 0.1093 | Val: 0.1809
# Epoch  29 | Train: 0.0958 | Val: 0.1790
# Epoch  30 | Train: 0.0940 | Val: 0.1782
# Epoch  31 | Train: 0.0963 | Val: 0.1787
# Epoch  32 | Train: 0.0782 | Val: 0.1812
# Epoch  33 | Train: 0.0744 | Val: 0.1812
# Epoch  34 | Train: 0.0716 | Val: 0.1797
# Epoch  35 | Train: 0.0923 | Val: 0.1801
# Epoch  36 | Train: 0.0733 | Val: 0.1765
# Epoch  37 | Train: 0.0640 | Val: 0.1815
# Epoch  38 | Train: 0.0650 | Val: 0.1752
# Epoch  39 | Train: 0.0615 | Val: 0.1783
# Epoch  40 | Train: 0.0541 | Val: 0.1826
# Epoch  41 | Train: 0.0525 | Val: 0.1758
# Epoch  42 | Train: 0.0516 | Val: 0.1757
# Epoch  43 | Train: 0.0759 | Val: 0.1767
# Epoch  44 | Train: 0.0486 | Val: 0.1811
# Epoch  45 | Train: 0.0490 | Val: 0.1832
# Epoch  46 | Train: 0.0632 | Val: 0.1803
# Epoch  47 | Train: 0.0938 | Val: 0.1786
# Epoch  48 | Train: 0.0487 | Val: 0.1793
# Epoch  49 | Train: 0.0477 | Val: 0.1825
# Epoch  50 | Train: 0.0454 | Val: 0.1847
# Epoch  51 | Train: 0.0597 | Val: 0.1790
# Epoch  52 | Train: 0.0601 | Val: 0.1786
# Epoch  53 | Train: 0.0433 | Val: 0.1815
# Epoch  54 | Train: 0.0429 | Val: 0.1822
# Epoch  55 | Train: 0.0495 | Val: 0.1754
# Epoch  56 | Train: 0.0411 | Val: 0.1772
# Epoch  57 | Train: 0.0400 | Val: 0.1795
# Epoch  58 | Train: 0.0405 | Val: 0.1800
# Epoch  59 | Train: 0.0416 | Val: 0.1821
# Epoch  60 | Train: 0.0409 | Val: 0.1810
# Epoch  61 | Train: 0.0367 | Val: 0.1807
# Epoch  62 | Train: 0.0909 | Val: 0.1793
# Epoch  63 | Train: 0.0380 | Val: 0.1790
# Epoch  64 | Train: 0.0372 | Val: 0.1817
# Epoch  65 | Train: 0.0364 | Val: 0.1826
# Epoch  66 | Train: 0.0368 | Val: 0.1765
# Epoch  67 | Train: 0.0414 | Val: 0.1814
# Epoch  68 | Train: 0.0346 | Val: 0.1864
# Epoch  69 | Train: 0.0346 | Val: 0.1809
# Epoch  70 | Train: 0.0601 | Val: 0.1818
# Epoch  71 | Train: 0.0364 | Val: 0.1780
# Epoch  72 | Train: 0.0360 | Val: 0.1825
# Epoch  73 | Train: 0.0409 | Val: 0.1821
# Epoch  74 | Train: 0.0347 | Val: 0.1820
# Epoch  75 | Train: 0.0956 | Val: 0.1900
# Epoch  76 | Train: 0.0407 | Val: 0.1841
# Epoch  77 | Train: 0.0431 | Val: 0.1844
# Epoch  78 | Train: 0.0411 | Val: 0.1814
# Epoch  79 | Train: 0.0362 | Val: 0.1782
# Epoch  80 | Train: 0.0365 | Val: 0.1794
# Epoch  81 | Train: 0.0333 | Val: 0.1842
# Epoch  82 | Train: 0.0316 | Val: 0.1858
# Epoch  83 | Train: 0.0489 | Val: 0.1802
# Epoch  84 | Train: 0.0316 | Val: 0.1824
# Epoch  85 | Train: 0.0337 | Val: 0.1833
# Epoch  86 | Train: 0.0415 | Val: 0.1840
# Epoch  87 | Train: 0.0461 | Val: 0.1792
# Epoch  88 | Train: 0.0330 | Val: 0.1783
# Epoch  89 | Train: 0.0314 | Val: 0.1771
# Epoch  90 | Train: 0.0327 | Val: 0.1796
# Epoch  91 | Train: 0.0560 | Val: 0.1800
# Epoch  92 | Train: 0.0329 | Val: 0.1783
# Epoch  93 | Train: 0.0340 | Val: 0.1802
# Epoch  94 | Train: 0.0859 | Val: 0.1826
# Epoch  95 | Train: 0.0423 | Val: 0.1792
# Epoch  96 | Train: 0.0327 | Val: 0.1862
# Epoch  97 | Train: 0.0770 | Val: 0.1816
# Epoch  98 | Train: 0.0347 | Val: 0.1741
# Epoch  99 | Train: 0.0308 | Val: 0.1776
# Epoch 100 | Train: 0.0318 | Val: 0.1844
# Epoch 101 | Train: 0.0532 | Val: 0.1849
# Epoch 102 | Train: 0.0325 | Val: 0.1810
#  ⇢ Early stopping triggered
#
# Predicted coefficients for 50-50 NaCl:
# Melt(K):   1107.2222
# Boil(K):   1128.9032
# rho_a  :      2.6799
# rho_b  :      0.0005
# mu1_a  :      0.1051
# mu1_b  :  22050.4141
# mu2_a  :     -1.2484
# mu2_b  :    875.5960
# mu2_c  :     -0.3318
# k_a    :      0.6481
# k_b    :     -0.0002
# cp_a   :     33.3480
# cp_b   :     -0.0001
#
# Derived properties at 900 K:
# rho :      2.2631
# muA :      2.0009
# muB :      0.5303
# k   :      0.5077
#
# Plotting results …
# Saved: actual_vs_predicted_coeff_Melt(K)_train.png
# Saved: actual_vs_predicted_coeff_Boil(K)_train.png
# Saved: actual_vs_predicted_coeff_rho_a_train.png
# Saved: actual_vs_predicted_coeff_rho_b_train.png
# Saved: actual_vs_predicted_coeff_mu1_a_train.png
# Saved: actual_vs_predicted_coeff_mu1_b_train.png
# Saved: actual_vs_predicted_coeff_mu2_b_train.png
# Saved: actual_vs_predicted_coeff_k_a_train.png
# Saved: actual_vs_predicted_coeff_cp_a_train.png
# Saved: actual_vs_predicted_coeff_Melt(K)_test.png
# Saved: actual_vs_predicted_coeff_Boil(K)_test.png
# Saved: actual_vs_predicted_coeff_rho_a_test.png
# Saved: actual_vs_predicted_coeff_rho_b_test.png
# Saved: actual_vs_predicted_coeff_mu1_a_test.png
# Saved: actual_vs_predicted_coeff_mu1_b_test.png
# Saved: actual_vs_predicted_coeff_mu2_b_test.png
# Saved: actual_vs_predicted_coeff_k_a_test.png
# Saved: actual_vs_predicted_coeff_cp_a_test.png
# Saved: actual_vs_predicted_coeff_cp_b_test.png
#
# Plotting actual vs. predicted thermo-physical properties …
# Saved: actual_vs_predicted_property_rho_train.png
# Saved: actual_vs_predicted_property_muA_train.png
# Saved: actual_vs_predicted_property_muB_train.png
# Saved: actual_vs_predicted_property_k_train.png
# Skipped cp (train) — not enough data
# Saved: actual_vs_predicted_property_rho_test.png
# Saved: actual_vs_predicted_property_muA_test.png
# Saved: actual_vs_predicted_property_muB_test.png
# Saved: actual_vs_predicted_property_k_test.png
# Skipped cp (test) — not enough data
#
# All plots saved in snn_prediction_plots
